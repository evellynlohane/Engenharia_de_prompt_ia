# %% [markdown]
# <a href="https://colab.research.google.com/github/evellynlohane/Engenharia_de_prompt_ia/blob/main/aula07_programacao_assistida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  x = (int('Digite um número inteiro: '))
except ValueError:
  print('Erro. Usuário digitou bagulho nada a ver. Seu primeiro número será 0.')

y = None

while y > 0:
  try:
    y = (int('Digite outro número inteiro: '))
    x += y
  except ValueError:
    print('Erro. IDIOTA, DIGITE NÚMERO INTEIRO.')
    continue
else:
  total = print(f'O resultado é: {x}')

# %% [markdown]
# #aula07
