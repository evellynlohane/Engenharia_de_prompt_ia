# %% [markdown]
# <a href="https://colab.research.google.com/github/evellynlohane/Engenharia_de_prompt_ia/blob/main/aula07_programacao_assistida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Define uma lista de números inteiros
numeros = [1,2,3]
# Inicializa a variável 'soma' com zero
soma = 0
# Inicializa a variável 'i' (contador) com zero
i = 0
# Loop 'while' para iterar sobre a lista 'numeros'
# O loop continua enquanto 'i' for menor que o tamanho da lista
while i < len(numeros):
  # Adiciona o número atual da lista à variável 'soma'
  soma += numeros[i]
  # Incrementa o contador 'i' para passar para o próximo número
  i += 1
# Imprime o valor final da soma
print(soma)
# Out:
# 6

# %% [markdown]
# #aula07: Progração Assistida // Evellyn Lohane
